# %% [markdown]
# ## Machine Learning - Supervised Learning -  Regression

# %%
import pandas as pd
data = pd.read_csv('http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv',index_col=0)
data.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
import seaborn as sns
# %matplotlib inline

# %%
## Seaborn Pairplot produced a matrix of plots with every X attributes with Y attribute

# %%
sns.pairplot(data,x_vars=['TV','radio','newspaper'],y_vars=['sales'],size=7,aspect=.7,kind='reg')

# %%
feature = ['TV','radio']
response = ['sales']
X = data[feature]
y = data[response]
from sklearn.model_selection import train_test_split
# the default split is 75% training and 25% test
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=1)

# %%
from sklearn.linear_model import LinearRegression

# %%
linr = LinearRegression()
linr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred = linr.predict(X_test)

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(y_test,y_pred)
# Out:
# 1.0477590411212605

# %%
metrics.mean_squared_error(y_test,y_pred)
# Out:
# 1.9262760418667437

# %%
import numpy as np
np.sqrt(metrics.mean_squared_error(y_test,y_pred))
# Out:
# 1.3879034699382893
